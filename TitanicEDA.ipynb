# %% [markdown]
# ## 1- IMPORT LIBRARIES

# %%
# Import Libraries for EDA and DAta Analysis
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style

sns.set(style="whitegrid")

# %% [markdown]
# ## 2- LOAD THE DATASET

# %%
# Load the Titanic dataset
df = pd.read_csv(r'C:\Users\Sanyam\Desktop\Sanyam\VS code\Libraries Python\titanic.csv')
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
# Display the first few rows
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ## 3- DATA OVERVIEW

# %%
# Display basic information about the dataset
df.info()

# Show statistical summary
df.describe()

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# ...

# %% [markdown]
# ## 4- DATA CLEANING

# %%
# Dropping columns that won't be used in analysis
df = df.drop(columns=['Ticket', 'Cabin', 'Name'])

# Fill missing values in 'Age' with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Drop rows with missing 'Embarked'
df = df.dropna(subset=['Embarked'])
# Out:
# C:\Users\Sanyam\AppData\Local\Temp\ipykernel_3748\3169945377.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %% [markdown]
# ## 5- VISUALIZE SURVIVAL RATES

# %% [markdown]
# ## 5.1 - OVERALL SURVIVAL RATES

# %%
# Overall survival rate
plt.figure(figsize=(5,5))
sns.countplot(x='Survived', data=df,color='GREEN')
plt.title('Overall Survival Rate')
plt.xticks([0, 1], ['Did Not Survive', 'Survived'])
plt.show()

# %% [markdown]
# ## 5.2 - SURVIVAL RATE BY GENDER

# %%
# Survival rate by gender
plt.figure(figsize=(5,5))
sns.barplot(x='Sex', y='Survived', data=df)
plt.title('Survival Rate by Gender')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# ## 5.3 - SURVIVAL RATES BY PASSENGER CLASS

# %%
# Survival rate by passenger class
plt.figure(figsize=(5,5))
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# ## 5.4 - AGE DISTRIBUTION OF SURVIVORS VS NON-SURVIVOR

# %%
# Age distribution
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', bins=30, kde=True)
plt.title('Age Distribution of Survivors vs. Non-Survivors')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 6- CORRELATION ANALYSIS

# %%
# Correlation heatmap
plt.figure(figsize=(10, 6))

# Convert categorical variables to numeric using one-hot encoding
df = pd.get_dummies(df, drop_first=True)  

# Calculate the correlation matrix
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## CONCLUSION

# %%
# 1- Women had a significantly higher survival rate compared to men.
# 2- Passengers in first class had better chances of survival than those in second or third class.
# 3- Younger passengers (under 18) had a higher survival rate compared to older passengers.
